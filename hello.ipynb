# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # hujadldh
# This is a sentence

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.array([1,2,3])
y=np.array([3,8,5])

a=np.array([0,4,5])
b=np.array([6,5,3])
plt.title("sample")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x,y)
plt.show()

# %%
studentscorelist=pd.read_csv("studentlist.csv")

# %%
studentscorelist.head()
# Out:
#        NAME  GENDER  AGE  SCORE
# 0   SHANKAR    MALE   17    543
# 1     ABDUL    MALE   55    494
# 2  RAJNEESH    MALE   24    492
# 3     KEVIN    MALE   19    222
# 4      DEVU  FEMALE   19    342
